# %%
import os
import warnings

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
""""
Run these commands to avoid Output truncated
"""
#pd.set_option("display.max_rows", None)  # Show all rows
#pd.set_option("display.max_columns", None)  # Show all columns
# Out:
# '"\nRun these commands to avoid Output truncated\n'

# %% [markdown]
# # Reading CSV file from local route

# %%
def read_csv(dataset_path):
    current_path = os.getcwd()
    aux_curr_path = current_path
    project_path = aux_curr_path.replace('/notebooks', '')
    dataset_path = os.path.join(project_path, dataset_path)
    return dataset_path

# %%
CSV_PATH = "dataset/Datos_Imgenes.csv"

# %%
df = pd.read_csv(read_csv(CSV_PATH))
df.head(3)
# Out:
#    Index                       Date                  Model ClassId  Page  \
# 0      0  2025-01-22T20:34:48-08:00  comprobante_domicilio     NaN     1
# 1      1  2025-01-22T20:34:48-08:00          recibo_nomina     NaN     1
# 2      2  2025-01-22T20:34:48-08:00          recibo_nomina     NaN     2
#
#    TotalPages  PagesProcessed  Fields  EmptyFields           ModelApplied  \
# 0           1               1      12            0   Lynx_ProofAddress_v6
# 1           2               1      15            0  Lynx_ProofPaysheet_v5
# 2           2               1      15            3  Lynx_ProofPaysheet_v5
#
#      ModelReported          Details  ConfR  ConfA  ConfW  Sharpness  Contrast  \
# 0              NaN  CDOM-CFE[1|0.2]  0.981  0.674  0.889       64.0      38.0
# 1  NOM-IMSS[1|0.2]  NOM-IMSS[1|0.2]  0.948  0.931  0.943      399.0      42.0
# 2  NOM-IMSS[1|0.2]  NOM-IMSS[1|0.2]  0.941  0.837  0.910      166.0      29.0
#
#    Clarity  Resolution DocType
# 0   2523.0       263.0     CFE
# 1  17045.0       672.0    IMSS
# 2   4866.0       233.0    IMSS

# %% [markdown]
# # Check missing values per column

# %% [markdown]
# By analyzing the data, we can identify that only two columns contain missing values: ClassID with 28,820 missing entries and ModelReported with 18,627. This is our initial assessment of the dataset; therefore, no actions, such as data removal, will be taken at this stage.

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# Index                 0
# Date                  0
# Model                 0
# ClassId           28820
# Page                  0
# TotalPages            0
# PagesProcessed        0
# Fields                0
# EmptyFields           0
# ModelApplied          0
# ModelReported     18627
# Details               0
# ConfR                 0
# ConfA                 0
# ConfW                 0
# Sharpness             0
# Contrast              0
# Clarity               0
# Resolution            0
# DocType               0
# dtype: int64

# %%
missing_values.plot(kind="bar", color="red", figsize=(8,5))
plt.xlabel("Columns")
plt.ylabel("Missing Values Count")
plt.title("Missing Values Per Column")
plt.show()

# %%
df.columns
# Out:
# Index(['Index', 'Date', 'Model', 'ClassId', 'Page', 'TotalPages',
#        'PagesProcessed', 'Fields', 'EmptyFields', 'ModelApplied',
#        'ModelReported', 'Details', 'ConfR', 'ConfA', 'ConfW', 'Sharpness',
#        'Contrast', 'Clarity', 'Resolution', 'DocType'],
#       dtype='object')

# %% [markdown]
# # Summary Stadistics for all columns

# %%
df.describe(include="all")
# Out:
#                Index                       Date          Model ClassId  \
# count   62960.000000                      62960          62960   34140
# unique           NaN                      27436              5       4
# top              NaN  2025-01-18T13:04:43-08:00  estado_cuenta     TXN
# freq             NaN                         49          34140   26556
# mean    47081.315025                        NaN            NaN     NaN
# std     27193.866099                        NaN            NaN     NaN
# min         0.000000                        NaN            NaN     NaN
# 25%     23511.500000                        NaN            NaN     NaN
# 50%     46975.000000                        NaN            NaN     NaN
# 75%     71010.250000                        NaN            NaN     NaN
# max     94108.000000                        NaN            NaN     NaN
#
#                 Page    TotalPages  PagesProcessed        Fields  \
# count   62960.000000  62960.000000    62960.000000  62960.000000
# unique           NaN           NaN             NaN           NaN
# top              NaN           NaN             NaN           NaN
# freq             NaN           NaN             NaN           NaN
# mean        2.934593      5.942186        3.326938     12.881210
# std         3.068428      4.682230        3.418311     13.533471
# min         1.000000      1.000000        1.000000      0.000000
# 25%         1.000000      2.000000        1.000000      0.000000
# 50%         2.000000      6.000000        1.000000     12.000000
# 75%         4.000000      8.000000        5.000000     27.000000
# max        48.000000     48.000000       15.000000     38.000000
#
#          EmptyFields        ModelApplied    ModelReported           Details  \
# count   62960.000000               62960            44333             62960
# unique           NaN                  10             1639              1905
# top              NaN  Lynx_BankingTXN_v5  NOM-IMSS[1|0.0]  CLIB-CLIB[1|0.0]
# freq             NaN               26467             1597              2952
# mean        3.495426                 NaN              NaN               NaN
# std         6.201645                 NaN              NaN               NaN
# min         0.000000                 NaN              NaN               NaN
# 25%         0.000000                 NaN              NaN               NaN
# 50%         0.000000                 NaN              NaN               NaN
# 75%         3.000000                 NaN              NaN               NaN
# max        21.000000                 NaN              NaN               NaN
#
#                ConfR         ConfA         ConfW     Sharpness      Contrast  \
# count   62960.000000  62960.000000  62960.000000  62960.000000  62960.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        0.917741      0.791809      0.879958    224.199117     43.402370
# std         0.128916      0.149599      0.091764    271.111842     11.423269
# min         0.001000      0.288000      0.152000      0.000000      0.000000
# 25%         0.914000      0.699000      0.849000     92.000000     36.000000
# 50%         0.956000      0.841000      0.904000    153.000000     43.000000
# 75%         0.993000      0.915000      0.930000    232.000000     50.000000
# max         0.999000      0.984000      0.993000  10209.000000    124.000000
#
#               Clarity    Resolution DocType
# count    62960.000000  62960.000000   62960
# unique            NaN           NaN      18
# top               NaN           NaN      EC
# freq              NaN           NaN   26556
# mean     10422.152731    457.302506     NaN
# std      14534.007181    200.917008     NaN
# min          0.000000      0.000000     NaN
# 25%       3612.000000    321.000000     NaN
# 50%       6363.000000    429.000000     NaN
# 75%       9869.000000    568.229623     NaN
# max     514200.000000   2405.000000     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62960 entries, 0 to 62959
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Index           62960 non-null  int64
#  1   Date            62960 non-null  object
#  2   Model           62960 non-null  object
#  3   ClassId         34140 non-null  object
#  4   Page            62960 non-null  int64
#  5   TotalPages      62960 non-null  int64
#  6   PagesProcessed  62960 non-null  int64
#  7   Fields          62960 non-null  int64
#  8   EmptyFields     62960 non-null  int64
#  9   ModelApplied    62960 non-null  object
#  10  ModelReported   44333 non-null  object
#  11  Details         62960 non-null  object
#  12  ConfR           62960 non-null  float64
#  13  ConfA           62960 non-null  float64
#  14  ConfW           62960 non-null  float64
#  15  Sharpness       62960 non-null  float64
#  16  Contrast        62960 non-null  float64
#  17  Clarity         62960 non-null  float64
#  18  Resolution      62960 non-null  float64
#  19  DocType         62960 non-null  object
# dtypes: float64(7), int64(6), object(7)
# memory usage: 9.6+ MB

# %%
categorical_columns = df.select_dtypes(include=["object", "category"]).columns.tolist()  # Convert to list
categorical_columns.remove("Date")  # Remove "Date" from the list
categorical_columns
# Out:
# ['Model', 'ClassId', 'ModelApplied', 'ModelReported', 'Details', 'DocType']

# %%
for i in categorical_columns:
    print(i)
# Out:
# Model
# ClassId
# ModelApplied
# ModelReported
# Details
# DocType

# %%
for i in categorical_columns:
    print(df[i].value_counts())
    print("-----")
# Out:
# Model
# estado_cuenta            34140
# recibo_nomina            10193
# ine                       9346
# comprobante_domicilio     5780
# carta_libranza            3501
# Name: count, dtype: int64
# -----
# ClassId
# TXN    26556
# APP     4261
# SUC     2581
# ATM      742
# Name: count, dtype: int64
# -----
# ModelApplied
# Lynx_BankingTXN_v5       26467
# Lynx_ProofPaysheet_v5     9722
# Lynx_IdProof_v1           9346
# Lynx_ATM_APP_v1           7568
# Lynx_ProofAddress_v6      5780
# Lynx_CLibranza_v2         3501
# Lynx_IMSS3_v2              469
# Lynx_BankingTXN_v6          89
# Lynx_ATM_APP_v2             16
# Lynx_IMSS3_v3                2
# Name: count, dtype: int64
# -----
# ModelReported
# NOM-IMSS[1|0.0]                    1597
# NOM-ISSSTE[1|0.0]                   756
# NOM-IMSS[1|0.2]                     691
# NOM-IMSS[1|0.3]                     682
# EC-EC(1)[3|0.3]                     603
# NOM-SEP(1)[1|0.0]                   530
# NOM-IMSS[1|0.1]                     499
# EC-EC[1|0.0]                        497
# NOM-IMSS[1|0.4]                     482
# EC-EC(1)[3|0.2]                     480
# EC-EC(1)[2|0.3]                     480
# EC-EC(1)[4|0.3]                     436
# NOM-ISSSTE[1|0.3]                   425
# NOM-PEMEX[1|0.0]                    401
# EC-EC(1)[2|0.2]                     396
# EC-EC(1)[3|0.4]                     390
# NOM-IMSS[1|90.0]                    385
# EC-EC(2)[4|0.3]                     352
# EC-EC(1)[5|0.3]                     325
# NOM-ISSSTE[1|0.2]                   317
# EC-EC(1)[4|0.2]                     308
# EC-EC(1)[4|0.4]                     304
# EC-EC[1|0.2]                        304
# EC-EC(1)[2|0.1]                     298
# EC-EC(0)[2|0.2]                     284
# EC-EC(1)[2|0.0]                     278
# EC-EC[1|0.3]                        271
# EC-EC[1|0.1]                        265
# NOM-ISSSTE[1|0.4]                   262
# EC-EC(0)[3|0.3]                     252
# EC-EC(1)[3|0.1]                     249
# EC-EC(0)[2|0.3]                     246
# EC-EC(1)[7|0.3]                     245
# NOM-SEP(1)[1|0.2]                   244
# EC-EC(2)[4|0.4]                     232
# EC-EC(1)[6|0.3]                     228
# NOM-SEP(1)[1|0.1]                   220
# EC-EC(1)[5|0.4]                     210
# EC-EC(2)[4|0.2]                     208
# EC-EC(1)[2|0.4]                     208
# EC-EC(1)[5|0.2]                     205
# EC-EC(2)[6|0.4]                     204
# EC-EC(2)[6|0.3]                     192
# EC-EC(0)[3|0.4]                     192
# EC-EC(0)[4|0.3]                     184
# EC-SUC(1)[2|0.2]                    182
# EC-EC(0)[2|0.1]                     182
# EC-SUC[1|0.0]                       179
# EC-SUC[1|0.2]                       178
# EC-EC(1)[7|0.4]                     175
# NOM-SEP(1)[1|0.3]                   175
# NOM-IMSS3[1|0.0]                    174
# NOM-IMSS[1|0.5]                     173
# EC-EC(1)[8|0.3]                     168
# EC-EC(0)[2|0.0]                     166
# EC-SUC[1|0.1]                       161
# EC-EC(0)[5|0.3]                     160
# NOM-ISSSTE[1|0.1]                   157
# EC-EC(1)[6|0.4]                     156
# EC-EC(1)[3|0.0]                     156
# EC-EC(0)[3|0.2]                     150
# EC-EC(1)[15|0.4]                    150
# EC-APP(1)[5|0.3]                    145
# EC-EC(1)[4|0.1]                     144
# EC-EC(0)[8|0.3]                     144
# NOM-IMSS[1|90.2]                    140
# EC-EC(2)[7|0.3]                     140
# EC-SUC(1)[2|0.3]                    140
# EC-APP(1)[3|0.3]                    138
# EC-SUC[1|0.3]                       136
# EC-EC(0)[4|0.4]                     136
# EC-APP(1)[4|0.2]                    136
# NOM-PEMEX[1|0.2]                    134
# EC-EC(2)[6|0.2]                     132
# EC-APP(1)[4|0.3]                    132
# EC-EC(0)[3|0.1]                     132
# EC-APP(1)[3|0.2]                    132
# EC-EC(1)[8|0.4]                     128
# NOM-IMSS[1|89.8]                    127
# EC-EC(2)[7|0.4]                     126
# EC-EC(0)[4|0.2]                     120
# EC-EC(2)[5|0.4]                     120
# EC-APP(1)[3|0.1]                    117
# EC-SUC(1)[3|0.4]                    117
# EC-EC(2)[5|0.2]                     115
# EC-EC(0)[6|0.3]                     114
# EC-APP(1)[7|0.4]                    112
# EC-EC(1)[3|0.5]                     111
# EC-EC(2)[5|0.3]                     110
# EC-APP(1)[4|0.4]                    108
# EC-EC(1)[6|0.2]                     108
# EC-EC(0)[2|90.0]                    106
# EC-EC(2)[8|0.3]                     104
# EC-EC(0)[13|0.3]                    104
# EC-SUC(1)[3|0.3]                    102
# EC-EC(2)[6|0.5]                     102
# EC-EC[1|0.4]                        101
# EC-EC(1)[5|0.5]                     100
# EC-EC(1)[10|0.3]                    100
# EC-APP(1)[5|0.4]                    100
# EC-APP(1)[5|0.2]                    100
# EC-EC(2)[8|0.4]                      96
# NOM-SEP(1)[1|0.4]                    95
# EC-EC(0)[5|0.4]                      95
# NOM-PEMEX[1|0.3]                     93
# EC-EC(2)[4|0.1]                      92
# EC-EC(0)[2|0.4]                      92
# EC-EC(2)[13|0.4]                     91
# EC-EC(1)[6|0.1]                      90
# EC-SUC(1)[2|0.4]                     90
# EC-EC(1)[4|0.5]                      88
# NOM-IMSS[1|89.7]                     88
# EC-SUC(1)[4|0.3]                     88
# EC-SUC(1)[2|0.1]                     88
# EC-EC(1)[2|90.0]                     88
# NOM-PEMEX[1|0.1]                     87
# EC-APP(1)[2|0.2]                     86
# EC-APP(1)[6|0.4]                     84
# EC-APP(1)[7|0.3]                     84
# EC-APP(1)[3|0.4]                     81
# NOM-IMSS[1|90.3]                     81
# EC-EC(1)[5|0.1]                      80
# EC-EC(2)[11|0.2]                     77
# EC-EC(1)[7|0.2]                      77
# EC-EC(0)[7|0.4]                      77
# EC-EC[1|90.0]                        77
# NOM-ISSSTE[1|0.5]                    77
# EC-EC(2)[4|0.5]                      76
# EC-SUC(1)[3|0.2]                     75
# EC-EC(1)[15|0.3]                     75
# EC-APP(1)[6|0.3]                     72
# EC-APP(1)[4|0.1]                     72
# EC-EC(1)[8|0.2]                      72
# EC-APP(1)[4|0.5]                     72
# EC-EC(1)[7|0.5]                      70
# EC-EC(2)[10|0.4]                     70
# EC-APP(1)[5|0.5]                     70
# EC-EC(2)[5|0.1]                      70
# EC-EC(1)[10|0.4]                     70
# NOM-PEMEX[1|0.4]                     69
# NOM-IMSS[1|90.1]                     68
# EC-EC(2)[4|0.0]                      68
# NOM-IMSS[1|0.6]                      68
# EC-SUC[1|0.4]                        67
# NOM-IMSS3[1|0.2]                     66
# EC-EC(1)[2|0.5]                      66
# EC-APP(1)[2|0.3]                     66
# EC-EC(2)[3|0.3]                      66
# NOM-IMSS[1|89.9]                     66
# EC-APP(1)[2|0.1]                     66
# EC-EC(2)[5|0.5]                      65
# EC-EC(1)[13|0.4]                     65
# NOM-IMSS[1|89.6]                     65
# EC-SUC(1)[5|0.3]                     65
# EC-APP(1)[2|0.0]                     64
# EC-EC(2)[9|0.4]                      63
# EC-EC(0)[7|0.3]                      63
# EC-EC(0)[3|0.0]                      63
# NOM-IMSS3[1|0.3]                     62
# EC-EC(0)[5|0.2]                      60
# EC-EC(1)[12|0.3]                     60
# EC-EC(0)[5|0.5]                      60
# EC-EC(2)[15|0.1]                     60
# EC-APP(1)[10|0.3]                    60
# EC-SUC(1)[2|0.5]                     60
# EC-APP(1)[7|0.2]                     56
# EC-APP(1)[8|0.3]                     56
# EC-EC(0)[4|0.5]                      56
# EC-EC(1)[14|0.6]                     56
# EC-EC(0)[8|0.4]                      56
# EC-APP(1)[14|0.4]                    56
# EC-EC(2)[7|0.2]                      56
# EC-EC(2)[14|0.3]                     56
# EC-APP(1)[8|0.4]                     56
# EC-EC(1)[14|0.4]                     56
# EC-EC(1)[14|0.3]                     56
# EC-EC(2)[14|3.5]                     56
# EC-EC(1)[8|0.1]                      56
# EC-APP(1)[11|0.4]                    55
# EC-APP(1)[6|0.2]                     54
# EC-EC(1)[6|0.5]                      54
# EC-APP(1)[6|0.1]                     54
# EC-EC(0)[6|0.2]                      54
# EC-EC(1)[9|0.3]                      54
# EC-EC(0)[4|0.1]                      52
# EC-EC(1)[13|0.3]                     52
# EC-EC(0)[3|0.5]                      51
# NOM-IMSS3[1|0.1]                     50
# EC-APP(1)[1|0.0]                     50
# EC-APP(1)[10|0.2]                    50
# EC-EC(2)[7|0.5]                      49
# EC-EC(1)[7|0.1]                      49
# EC-EC(1)[8|0.5]                      48
# EC-EC(2)[8|0.5]                      48
# EC-SUC(1)[4|0.2]                     48
# NOM-IMSS[1|90.4]                     47
# NOM-IMSS[1|0.7]                      46
# EC-APP(1)[2|0.4]                     46
# EC-EC(3)[3|90.0]                     45
# EC-EC(0)[15|0.2]                     45
# EC-EC(2)[15|0.3]                     45
# EC-APP(1)[9|0.4]                     45
# EC-APP(1)[9|0.3]                     45
# EC-APP(1)[5|0.6]                     45
# EC-EC(2)[15|2.2]                     45
# EC-EC(2)[15|0.4]                     45
# EC-EC(0)[5|0.1]                      45
# EC-EC(1)[11|0.3]                     44
# EC-EC(0)[2|0.5]                      44
# EC-SUC(1)[2|0.0]                     44
# EC-EC(0)[11|0.4]                     44
# EC-APP(1)[7|0.5]                     42
# EC-APP(1)[1|0.1]                     42
# EC-EC(1)[14|0.2]                     42
# EC-EC(2)[14|0.2]                     42
# EC-EC(2)[2|0.2]                      42
# EC-APP(1)[14|0.3]                    42
# EC-EC(1)[10|0.2]                     40
# EC-APP(1)[10|0.4]                    40
# EC-EC(2)[10|0.3]                     40
# EC-EC(1)[4|0.0]                      40
# EC-EC(0)[4|90.0]                     40
# EC-EC(0)[10|0.4]                     40
# EC-APP(1)[1|0.2]                     39
# EC-SUC(1)[3|0.1]                     39
# EC-EC(2)[3|0.2]                      39
# EC-APP(1)[13|0.4]                    39
# EC-EC(2)[2|0.3]                      38
# EC-ATM(1)[1|0.0]                     37
# EC-EC(1)[12|0.4]                     36
# EC-EC(0)[4|0.0]                      36
# EC-SUC(1)[4|0.4]                     36
# EC-EC(1)[9|0.5]                      36
# EC-SUC(1)[4|0.5]                     36
# EC-APP(1)[6|0.5]                     36
# EC-EC(0)[9|0.4]                      36
# EC-EC(2)[6|0.1]                      36
# EC-EC(0)[6|0.4]                      36
# EC-APP(1)[9|0.2]                     36
# EC-EC(2)[9|0.5]                      36
# EC-EC(1)[9|0.4]                      36
# EC-APP(1)[12|0.3]                    36
# EC-APP(1)[3|0.5]                     36
# EC-EC(1)[5|0.0]                      35
# EC-SUC[1|0.5]                        35
# EC-EC(1)[7|0.6]                      35
# EC-APP(1)[5|0.1]                     35
# EC-ATM(1)[2|0.6]                     34
# NOM-IMSS[1|0.0|CamScanner]           34
# EC-ATM(1)[2|0.3]                     34
# EC-EC(2)[11|0.3]                     33
# EC-APP(1)[11|0.3]                    33
# EC-EC(2)[3|90.0]                     33
# EC-EC(1)[11|1.3]                     33
# EC-SUC(1)[3|0.5]                     33
# EC-EC(2)[3|0.4]                      33
# EC-EC(1)[11|0.4]                     33
# EC-EC(2)[11|0.4]                     33
# EC-APP(1)[8|0.2]                     32
# EC-EC(1)[8|1.4]                      32
# EC-EC(0)[8|0.5]                      32
# EC-EC(8)[8|90.5]                     32
# EC-SUC(1)[8|0.5]                     32
# EC-EC(2)[2|90.0]                     32
# EC-EC(2)[8|0.2]                      32
# EC-SUC(1)[6|0.3]                     30
# EC-EC(3)[15|0.4]                     30
# EC-ATM(1)[1|0.3]                     30
# EC-SUC(1)[5|0.2]                     30
# EC-EC(1)[3|0.6]                      30
# EC-EC(1)[15|0.2]                     30
# EC-EC(0)[3|90.0]                     30
# EC-EC(0)[15|0.3]                     30
# EC-EC(0)[15|0.6|CamScanner]          30
# EC-EC(1)[15|1.2]                     30
# EC-EC(1)[15|0.5]                     30
# EC-EC(0)[3|90.3]                     30
# EC-APP(1)[1|0.3]                     30
# EC-EC(1)[15|2.1]                     30
# EC-EC(0)[15|0.4]                     30
# EC-APP(1)[15|0.3]                    30
# EC-EC[1|0.5]                         29
# EC-EC(2)[14|0.5]                     28
# EC-EC(1)[7|1.2]                      28
# EC-EC(0)[14|0.5]                     28
# EC-EC(0)[14|0.4]                     28
# EC-EC[1|0.0|CamScanner]              28
# EC-EC(1)[14|1.4]                     28
# EC-ATM(1)[1|0.2]                     27
# EC-EC(2)[3|0.1]                      27
# EC-EC(0)[9|0.3]                      27
# EC-EC(2)[9|0.3]                      27
# EC-EC(1)[13|5.6]                     26
# EC-EC(1)[13|0.5]                     26
# EC-APP(1)[13|0.5]                    26
# EC-APP(1)[13|0.3]                    26
# EC-EC(0)[13|0.4]                     26
# EC-EC(1)[13|1.3]                     26
# EC-EC(1)[5|0.2|CamScanner]           25
# EC-EC(0)[5|0.3|CamScanner]           25
# EC-EC(0)[5|0.6]                      25
# EC-EC(0)[5|90.0]                     25
# EC-APP(1)[5|0.8]                     25
# EC-EC(0)[5|0.0]                      25
# NOM-SEP(1)[1|0.5]                    25
# EC-EC(1)[12|0.2]                     24
# EC-APP(1)[3|0.0]                     24
# EC-EC(1)[4|0.6]                      24
# EC-APP(1)[12|0.5]                    24
# EC-EC(2)[8|1.0]                      24
# EC-EC(7)[12|90.6]                    24
# EC-EC(5)[8|89.8]                     24
# EC-EC(1)[8|1.3]                      24
# EC-ATM(1)[2|0.4]                     24
# EC-EC(3)[4|90.0]                     24
# EC-EC(4)[4|90.0]                     24
# EC-EC(1)[4|0.3|CamScanner]           24
# EC-EC(2)[8|1.2]                      24
# EC-EC(0)[8|0.4|CamScanner]           24
# EC-EC(0)[6|0.6]                      24
# NOM-ISSSTE[1|0.6]                    24
# EC-EC(3)[6|0.3]                      24
# EC-EC(1)[3|90.0]                     24
# EC-EC(1)[8|0.8]                      24
# EC-SUC(1)[4|0.1]                     24
# EC-ATM(1)[1|0.1]                     22
# EC-EC(1)[11|0.6|CamScanner]          22
# EC-EC(1)[11|0.5]                     22
# EC-EC(2)[11|0.1]                     22
# EC-EC(0)[2|0.2] CC1                  22
# EC-EC(1)[11|1.2]                     22
# EC-EC(1)[2|0.3|CamScanner]           22
# EC-EC(1)[7|1.0]                      21
# EC-EC(0)[7|0.5]                      21
# EC-EC(1)[7|0.0]                      21
# EC-EC(1)[7|90.0]                     21
# EC-EC(0)[7|90.0]                     21
# EC-EC(0)[7|0.2]                      21
# EC-EC(2)[7|0.1]                      21
# NOM-SEP(1)[1|0.6]                    21
# EC-EC(0)[3|1.1]                      21
# EC-EC(1)[7|0.7]                      21
# EC-EC(3)[5|0.3]                      20
# EC-EC(0)[4|0.3] CC2                  20
# EC-EC(2)[2|0.0]                      20
# EC-EC(1)[10|0.0]                     20
# EC-EC(2)[10|0.5]                     20
# EC-EC(1)[10|90.0]                    20
# EC-EC(0)[5|0.7]                      20
# EC-EC(1)[10|0.8]                     20
# EC-EC(0)[10|0.3]                     20
# EC-EC(0)[10|90.4]                    20
# EC-EC(2)[4|0.2|CamScanner]           20
# EC-EC(2)[10|0.6]                     20
# EC-EC(1)[5|2.3]                      20
# EC-EC(1)[5|0.3|CamScanner]           20
# EC-APP(1)[4|0.6]                     20
# EC-ATM(1)[2|0.2]                     20
# EC-ATM(1)[4|0.3]                     20
# EC-EC(1)[10|0.5]                     20
# EC-EC[1|0.1|CamScanner]              19
# EC-EC(1)[3|0.7]                      18
# EC-APP(1)[9|0.5]                     18
# EC-EC(3)[9|0.2]                      18
# EC-EC(1)[9|1.3]                      18
# EC-APP(1)[6|0.6]                     18
# EC-EC(0)[6|90.0]                     18
# EC-EC(2)[9|1.1]                      18
# EC-EC(0)[9|0.1]                      18
# EC-EC(2)[6|0.3|CamScanner]           18
# EC-EC(1)[9|1.6]                      18
# EC-EC(0)[9|90.4]                     18
# EC-EC(1)[6|1.3]                      18
# EC-EC(1)[6|1.1]                      18
# EC-ATM(1)[2|0.1]                     18
# NOM-PEMEX[1|0.0|CamScanner]          18
# EC-EC(1)[9|0.2]                      18
# EC-EC(9)[9|90.0|CamScanner]          18
# EC-EC(0)[9|0.5]                      18
# EC-EC(0)[6|0.5]                      18
# EC-SUC(1)[6|0.2]                     18
# EC-EC(1)[6|1.2]                      18
# EC-EC(1)[3|0.3|CamScanner]           18
# NOM-IMSS3[1|0.4]                     17
# EC-EC[1|90.2]                        17
# EC-EC(1)[2|89.7]                     16
# EC-EC(1)[4|90.0]                     16
# EC-APP(1)[4|0.7]                     16
# EC-ATM(1)[1|0.4]                     16
# EC-EC(6)[8|90.0]                     16
# EC-APP(1)[2|0.5]                     16
# EC-EC(2)[2|0.4]                      16
# EC-EC(0)[2|0.3] CC1                  16
# EC-APP(1)[8|0.7]                     16
# EC-EC(2)[8|0.0]                      16
# EC-EC(0)[2|0.0] CC1                  16
# EC-EC(0)[8|0.1]                      16
# EC-EC(0)[8|0.2]                      16
# EC-EC(2)[8|0.6]                      16
# NOM-IMSS3[1|0.5]                     16
# EC-EC(0)[2|0.3|CamScanner]           16
# EC-EC(1)[2|0.2|CamScanner]           16
# EC-EC(0)[2|0.2|CamScanner]           16
# EC-EC(2)[8|1.1]                      16
# EC-APP(1)[8|0.5]                     16
# EC-EC(0)[4|90.1]                     16
# EC-EC(0)[8|1.5]                      16
# EC-EC(4)[4|90.5]                     16
# EC-EC(1)[8|0.6|CamScanner]           16
# EC-EC(1)[8|1.1]                      16
# EC-EC(1)[8|1.0]                      16
# NOM-IMSS[1|89.5]                     16
# EC-EC(1)[8|0.7]                      16
# NOM-IMSS[1|0.8]                      16
# EC-EC(1)[2|0.4|CamScanner]           16
# EC-APP(1)[4|0.0]                     16
# EC-EC(1)[15|1.5]                     15
# EC-EC(2)[15|0.5]                     15
# EC-EC(1)[15|1.7]                     15
# EC-SUC(1)[5|0.6]                     15
# EC-EC(12)[15|90.6]                   15
# EC-EC(1)[15|0.9]                     15
# EC-EC(1)[5|0.1|CamScanner]           15
# EC-EC(1)[5|1.1]                      15
# EC-APP(1)[15|0.4]                    15
# EC-EC(11)[15|90.7]                   15
# EC-EC(1)[15|0.5|CamScanner]          15
# EC-EC(2)[3|0.0]                      15
# EC-EC(1)[15|0.6]                     15
# EC-EC(8)[15|90.0]                    15
# EC-EC(5)[5|90.0]                     15
# EC-APP(1)[15|0.1]                    15
# EC-EC(1)[3|0.2|CamScanner]           15
# EC-EC(3)[5|0.2]                      15
# EC-EC(2)[5|0.5|CamScanner]           15
# EC-EC(2)[15|1.3]                     15
# EC-EC(4)[5|90.5]                     15
# EC-EC(1)[15|1.6]                     15
# EC-ATM(1)[5|90.8]                    15
# EC-SUC(1)[5|0.5]                     15
# EC-EC(1)[5|0.4|CamScanner]           15
# EC-EC(1)[3|0.2] CC1                  15
# EC-EC(0)[15|1.3]                     15
# EC-EC(0)[15|0.5]                     15
# EC-EC(15)[15|90.6]                   15
# EC-EC(0)[3|0.4|CamScanner]           15
# EC-EC(4)[5|90.4]                     15
# EC-SUC[1|0.0|CamScanner]             15
# EC-APP(1)[3|0.6]                     15
# EC-EC(4)[14|0.5]                     14
# EC-EC(1)[14|0.5]                     14
# EC-EC(2)[14|0.4]                     14
# EC-APP(1)[2|0.6]                     14
# EC-EC(0)[14|0.2] CC1                 14
# EC-APP(1)[7|0.7]                     14
# EC-EC(2)[14|4.5]                     14
# EC-EC(2)[14|4.0]                     14
# EC-EC(3)[7|0.4]                      14
# EC-SUC(1)[7|0.2]                     14
# EC-EC(0)[14|3.2]                     14
# EC-EC(0)[7|0.5] SC                   14
# EC-EC(2)[7|90.0]                     14
# EC-EC(2)[7|1.3]                      14
# EC-EC(1)[14|0.8]                     14
# EC-APP(1)[14|0.7]                    14
# EC-EC(0)[14|0.2]                     14
# EC-EC(0)[7|0.4|CamScanner]           14
# EC-EC(1)[7|90.4]                     14
# EC-EC(6)[7|90.4]                     14
# EC-EC(5)[14|90.3]                    14
# EC-EC(1)[14|91.3]                    14
# EC-APP(1)[14|0.5]                    14
# EC-EC(6)[7|90.0]                     14
# EC-SUC(1)[7|0.4]                     14
# EC-EC(0)[7|0.1]                      14
# EC-APP(1)[14|0.6]                    14
# EC-EC(0)[14|0.3]                     14
# EC-EC(9)[14|90.5]                    14
# EC-EC(1)[7|1.1]                      14
# EC-EC(2)[2|90.5]                     14
# EC-APP(1)[7|0.9]                     14
# EC-EC(0)[7|1.0]                      14
# NOM-PEMEX[1|0.5]                     14
# EC-EC(3)[7|0.1|CamScanner]           14
# EC-EC(2)[14|1.3]                     14
# EC-EC(1)[14|0.9]                     14
# EC-EC(0)[14|4.2]                     14
# EC-EC[1|0.0] SC                      13
# EC-EC(2)[13|0.3]                     13
# EC-EC(0)[13|3.4]                     13
# EC-APP(1)[13|0.3|CamScanner]         13
# EC-EC(2)[13|0.2]                     13
# EC-EC(1)[13|90.7]                    13
# EC-EC(1)[13|0.1]                     13
# EC-EC(1)[13|0.2]                     13
# EC-EC(2)[13|2.2]                     13
# EC-EC(1)[13|1.1]                     13
# EC-EC(2)[13|1.2]                     13
# EC-EC(4)[13|0.9]                     13
# EC-EC(0)[13|0.2]                     13
# EC-EC(1)[13|2.0]                     13
# EC-EC(6)[13|90.2]                    13
# EC-EC(1)[13|0.4|CamScanner]          13
# EC-EC(1)[13|3.1]                     13
# EC-EC(0)[12|90.2]                    12
# EC-ATM(1)[4|1.4]                     12
# EC-EC(1)[12|2.2]                     12
# EC-EC(2)[6|89.8|CamScanner]          12
# EC-EC(1)[3|89.8]                     12
# EC-EC(2)[12|90.5]                    12
# EC-EC(2)[12|0.3|CamScanner]          12
# EC-EC(1)[3|0.1|CamScanner]           12
# EC-EC(4)[4|0.2]                      12
# EC-EC(2)[12|90.0]                    12
# EC-EC(1)[6|2.2]                      12
# EC-EC(2)[12|2.2]                     12
# EC-EC(0)[12|0.3]                     12
# EC-EC(2)[12|2.4]                     12
# EC-EC(12)[12|90.4]                   12
# EC-APP(1)[12|0.7]                    12
# EC-APP(1)[12|2.5]                    12
# EC-EC(4)[4|90.4]                     12
# EC-APP(1)[1|0.4]                     12
# EC-EC(0)[6|1.0]                      12
# EC-EC(6)[12|90.1]                    12
# EC-EC(0)[12|0.6]                     12
# EC-EC(0)[12|2.5]                     12
# EC-EC(3)[4|0.4]                      12
# EC-EC(0)[2|0.4|CamScanner]           12
# EC-EC(2)[12|0.3]                     12
# EC-ATM(1)[2|2.0]                     12
# EC-EC(0)[12|0.2]                     12
# EC-EC(0)[3|0.4] CC1                  12
# EC-EC(0)[4|0.2] CC2                  12
# EC-EC(1)[12|0.8]                     12
# EC-EC(2)[6|0.6]                      12
# EC-EC(2)[12|0.5]                     12
# EC-EC(0)[3|0.8]                      12
# EC-EC(2)[4|0.1] CC2                  12
# EC-EC(1)[2|89.8]                     12
# EC-EC(0)[2|0.1] CC1                  12
# EC-EC(0)[4|0.2] CC1                  12
# EC-EC(0)[4|0.4|CamScanner]           12
# EC-SUC(1)[2|0.2|CamScanner]          12
# EC-EC(0)[4|0.4] CC1                  12
# EC-EC(2)[6|90.0]                     12
# EC-SUC(1)[6|1.1]                     12
# EC-EC(0)[4|90.1|CamScanner]          12
# NOM-PEMEX[1|0.6]                     12
# EC-EC(2)[3|90.2]                     12
# EC-EC(0)[3|89.8]                     12
# EC-EC(2)[4|0.6]                      12
# EC-EC(1)[6|0.0]                      12
# EC-EC(0)[4|0.3|CamScanner]           12
# NOM-IMSS[1|0.2|CamScanner]           12
# EC-EC(1)[2|0.0|CamScanner]           12
# EC-EC(1)[6|0.7]                      12
# EC-EC(3)[3|90.2]                     12
# EC-EC(0)[3|1.2]                      12
# EC-EC(1)[12|1.0]                     12
# EC-EC(0)[3|0.6]                      12
# EC-APP(1)[4|0.9]                     12
# EC-ATM(1)[2|0.5]                     12
# EC-EC(0)[3|1.3]                      12
# EC-EC(3)[6|0.4]                      12
# EC-EC(3)[6|0.1]                      12
# EC-EC(12)[12|90.3]                   12
# EC-EC(0)[4|0.6]                      12
# EC-EC(0)[12|5.2]                     12
# EC-EC(0)[6|0.1]                      12
# EC-EC(0)[6|0.3|CamScanner]           12
# EC-EC(1)[12|1.4]                     12
# EC-EC(1)[4|2.1]                      12
# EC-EC(1)[6|90.5]                     12
# EC-EC(2)[12|0.4]                     12
# EC-EC(0)[2|0.0|CamScanner]           12
# EC-ATM(1)[4|0.4|CamScanner]          12
# EC-EC(1)[11|0.6]                     11
# EC-EC(0)[11|1.1]                     11
# EC-SUC(1)[11|0.4]                    11
# EC-EC(1)[11|0.9]                     11
# EC-EC(11)[11|90.8]                   11
# EC-EC(0)[11|1.5]                     11
# EC-ATM(1)[1|0.5]                     11
# EC-APP(1)[11|0.2]                    11
# EC-EC(0)[11|90.0]                    11
# NOM-IMSS3[1|0.0|CamScanner]          11
# EC-EC(1)[11|0.2|CamScanner]          11
# EC-EC(3)[11|0.4]                     11
# EC-EC(0)[11|2.6]                     11
# EC-EC(6)[11|90.6]                    11
# EC-APP(1)[11|1.1]                    11
# EC-EC(4)[11|0.3]                     11
# EC-EC(2)[11|0.5]                     11
# EC-EC[1|90.4]                        11
# EC-EC(0)[11|0.3] CC1                 11
# EC-EC[1|0.3|CamScanner]              11
# EC-EC(0)[11|0.3|CamScanner]          11
# EC-EC(1)[11|0.2]                     11
# EC-APP(1)[11|0.8]                    11
# EC-EC(1)[11|4.4]                     11
# EC-EC(11)[11|90.5]                   11
# EC-EC(1)[11|0.7]                     11
# EC-EC(1)[5|1.6]                      10
# EC-APP(1)[2|0.7]                     10
# EC-EC(1)[10|0.1]                     10
# NOM-ISSSTE[1|0.7]                    10
# EC-EC(0)[10|1.3]                     10
# EC-EC(0)[10|0.7]                     10
# EC-EC(2)[10|1.5]                     10
# EC-EC(7)[10|90.0]                    10
# EC-EC(0)[5|1.3]                      10
# EC-APP(1)[10|1.1]                    10
# EC-EC(2)[5|0.2|CamScanner]           10
# EC-EC(0)[10|2.5]                     10
# EC-EC(0)[10|2.4]                     10
# EC-EC(1)[2|0.6]                      10
# EC-EC(1)[10|0.6|CamScanner]          10
# EC-ATM(1)[2|1.2]                     10
# EC-ATM(1)[2|0.7]                     10
# EC-EC(1)[5|1.3]                      10
# EC-EC(2)[10|0.1|CamScanner]          10
# EC-EC(5)[5|90.6]                     10
# EC-EC(0)[10|2.3]                     10
# NOM-SEP(1)[1|0.0|CamScanner]         10
# EC-EC(10)[10|90.1]                   10
# EC-EC(3)[10|0.3]                     10
# EC-ATM(1)[2|0.6|CamScanner]          10
# EC-EC(3)[10|0.3|CamScanner]          10
# EC-EC(2)[10|2.1]                     10
# EC-EC(1)[10|3.2]                     10
# EC-APP(1)[5|0.4|CamScanner]          10
# EC-EC(1)[5|1.4]                      10
# EC-EC[1|90.3]                        10
# EC-EC(9)[10|90.2]                    10
# EC-EC(1)[10|0.4|CamScanner]          10
# EC-EC(1)[10|1.3]                     10
# EC-EC(0)[5|3.4]                      10
# EC-EC(1)[10|1.4|CamScanner]          10
# EC-ATM(1)[2|0.9]                     10
# EC-SUC(1)[2|0.3|CamScanner]          10
# EC-EC(1)[5|90.7]                     10
# EC-EC(0)[5|0.4] CC1                  10
# EC-EC(0)[5|0.2] CC1                  10
# EC-EC(2)[2|0.1]                      10
# EC-EC(1)[10|0.3|CamScanner]          10
# EC-EC(1)[5|0.6]                      10
# EC-EC[1|89.7]                        10
# EC-EC(3)[5|90.5]                     10
# EC-EC(3)[5|90.4]                     10
# EC-EC(0)[2|89.8]                     10
# EC-EC(0)[10|2.1]                     10
# EC-EC(0)[2|90.3]                     10
# EC-SUC(1)[5|0.4]                     10
# EC-EC(3)[5|0.4]                      10
# NOM-IMSS[1|0.9]                      10
# EC-EC(0)[10|90.5|CamScanner]         10
# EC-EC(0)[10|1.1]                     10
# NOM-ISSSTE[1|0.0|CamScanner]         10
# EC-EC(1)[5|89.9]                     10
# EC-EC(0)[5|1.2]                      10
# EC-ATM(1)[2|1.1]                     10
# EC-EC(0)[5|90.3]                     10
# EC-EC(1)[10|2.2]                     10
# EC-EC(2)[10|0.1]                     10
# EC-EC(4)[5|0.4]                      10
# EC-EC(4)[5|90.0]                     10
# NOM-SEP(1)[1|0.7]                    10
# EC-EC(7)[10|90.1]                    10
# EC-EC(1)[10|1.4]                     10
# EC-APP(1)[10|0.3|CamScanner]         10
# EC-EC(0)[2|1.1]                      10
# EC-EC(6)[10|90.5]                    10
# EC-EC(0)[10|0.2]                     10
# EC-EC(2)[10|1.3]                     10
# EC-EC(8)[10|90.3]                    10
# EC-EC(2)[5|0.4|CamScanner]           10
# EC-APP(1)[10|0.7]                    10
# EC-EC(2)[10|1.1]                     10
# EC-EC(2)[9|0.5|CamScanner]            9
# NOM-IMSS[1|0.3|CamScanner]            9
# EC-EC(4)[9|0.2|CamScanner]            9
# EC-SUC(1)[3|0.6]                      9
# EC-EC(2)[3|90.3]                      9
# EC-EC(0)[9|0.7]                       9
# EC-APP(1)[3|0.7]                      9
# EC-EC(1)[3|0.0|CamScanner]            9
# EC-EC(0)[3|90.1]                      9
# EC-EC(2)[9|0.2]                       9
# EC-EC[1|0.2|CamScanner]               9
# EC-EC(1)[3|0.4|CamScanner]            9
# EC-APP(1)[9|0.7]                      9
# EC-EC(9)[9|90.5]                      9
# EC-EC(3)[9|0.7|CamScanner]            9
# EC-EC(0)[9|90.1]                      9
# EC-EC(3)[3|90.5]                      9
# EC-EC(0)[9|1.6]                       9
# EC-EC(0)[3|0.3] CC1                   9
# EC-EC[1|0.4|CamScanner]               9
# EC-EC(0)[9|90.0]                      9
# EC-EC(1)[3|0.6] CC1                   9
# EC-EC(1)[3|0.4] CC1                   9
# EC-EC(2)[3|0.5]                       9
# EC-EC[1|90.0] SC                      9
# EC-EC[1|0.2] SC                       9
# EC-EC(2)[9|0.8]                       9
# EC-APP(1)[9|1.2]                      9
# EC-EC(1)[3|2.3]                       9
# EC-EC(0)[3|1.0]                       9
# EC-SUC(1)[3|0.0]                      9
# EC-SUC(1)[3|1.3]                      9
# EC-EC(1)[3|3.3]                       9
# EC-EC(2)[3|90.5]                      9
# EC-EC(4)[9|90.0]                      9
# EC-EC(2)[9|1.4]                       9
# EC-EC(9)[9|90.4|CamScanner]           9
# EC-EC(1)[3|0.5|CamScanner]            9
# EC-EC(6)[9|90.0]                      9
# EC-EC(0)[9|4.2]                       9
# EC-EC(0)[3|0.2|CamScanner]            9
# EC-EC[1|89.6]                         9
# EC-EC(2)[3|0.2|CamScanner]            9
# EC-EC(0)[9|0.6]                       9
# EC-EC(2)[9|2.3]                       9
# EC-EC(2)[9|1.2]                       9
# EC-EC(2)[9|90.2]                      9
# EC-EC(1)[9|5.3]                       9
# EC-EC(1)[3|0.8]                       9
# EC-EC(1)[9|0.4|CamScanner]            9
# EC-EC(3)[9|0.1|CamScanner]            9
# EC-EC(6)[9|90.3]                      9
# NOM-ISSSTE[1|90.0]                    9
# EC-ATM(1)[9|7.8]                      9
# EC-APP(1)[9|0.6]                      9
# EC-EC(7)[9|90.0]                      9
# EC-EC(3)[3|90.3]                      9
# EC-APP(1)[3|0.2|CamScanner]           9
# EC-APP(1)[3|1.0]                      9
# EC-EC(1)[9|0.1]                       9
# EC-EC(3)[8|90.1]                      8
# EC-EC(2)[8|0.6|CamScanner]            8
# EC-EC(0)[2|0.6]                       8
# EC-EC(4)[8|0.4]                       8
# EC-ATM(1)[4|0.4]                      8
# EC-EC(1)[8|0.3|CamScanner]            8
# EC-ATM(1)[4|0.7]                      8
# EC-EC(1)[8|3.5]                       8
# EC-EC(0)[8|90.5]                      8
# EC-APP(1)[8|90.3]                     8
# EC-EC(19)[8|0.2]                      8
# EC-SUC(1)[4|90.4]                     8
# EC-EC(3)[8|0.3]                       8
# EC-EC(3)[4|0.2]                       8
# EC-EC(1)[4|0.4|CamScanner]            8
# EC-EC(4)[4|91.3]                      8
# EC-EC(1)[4|1.3]                       8
# EC-ATM(1)[2|0.4|CamScanner]           8
# EC-EC(0)[4|3.1]                       8
# EC-EC(6)[8|90.1]                      8
# EC-SUC(1)[4|0.6]                      8
# EC-APP(1)[4|0.6|CamScanner]           8
# EC-EC(3)[8|0.2]                       8
# EC-APP(1)[4|1.0]                      8
# EC-EC(8)[8|90.1]                      8
# EC-EC(1)[8|3.3]                       8
# EC-EC(7)[8|90.0]                      8
# EC-EC(0)[4|0.9]                       8
# EC-APP(1)[8|0.6]                      8
# EC-EC(1)[4|1.2]                       8
# EC-EC(1)[2|90.2]                      8
# EC-EC(3)[4|0.3]                       8
# EC-EC(4)[8|90.0]                      8
# EC-EC(0)[4|89.9|CamScanner]           8
# EC-EC(3)[8|90.2|CamScanner]           8
# EC-EC(1)[8|88.1]                      8
# EC-EC(6)[8|90.6]                      8
# EC-EC(1)[8|90.5]                      8
# EC-EC(1)[8|1.5]                       8
# EC-APP(1)[4|0.7|CamScanner]           8
# EC-EC(1)[8|0.4|CamScanner]            8
# EC-EC(2)[4|0.8]                       8
# EC-EC(8)[8|90.0]                      8
# EC-EC(6)[8|90.3]                      8
# EC-ATM(1)[2|2.1]                      8
# EC-SUC(1)[8|0.7]                      8
# EC-EC(0)[2|90.1]                      8
# EC-EC(4)[8|89.6]                      8
# EC-EC(2)[8|2.3]                       8
# EC-EC(1)[8|0.6]                       8
# EC-EC(2)[4|0.3|CamScanner]            8
# EC-EC(3)[4|90.4]                      8
# EC-EC(0)[8|1.6]                       8
# EC-EC(1)[8|2.1]                       8
# EC-EC(1)[8|4.2]                       8
# EC-EC(4)[8|0.1]                       8
# EC-EC(1)[2|90.3]                      8
# EC-SUC(1)[8|0.4]                      8
# EC-EC(2)[8|1.3]                       8
# EC-EC(1)[8|2.3]                       8
# EC-SUC(1)[2|0.0|CamScanner]           8
# EC-EC(4)[8|90.1]                      8
# EC-EC(1)[8|1.7]                       8
# EC-APP(1)[8|0.1]                      8
# EC-EC(3)[8|0.5]                       8
# EC-EC(8)[8|90.4]                      8
# EC-EC(1)[4|0.8]                       8
# EC-EC(1)[4|0.0|CamScanner]            8
# EC-EC(6)[8|89.9]                      8
# EC-EC(1)[8|1.2]                       8
# EC-EC(2)[8|0.7]                       8
# EC-EC(0)[2|1.3]                       8
# EC-EC(1)[4|90.2]                      8
# EC-EC[1|89.8]                         8
# EC-APP(1)[4|90.2]                     8
# EC-EC(1)[4|90.3]                      8
# EC-EC(0)[2|1.0]                       8
# EC-SUC[1|0.4|CamScanner]              8
# NOM-IMSS[1|0.1|CamScanner]            8
# EC-EC(1)[2|90.4]                      8
# EC-EC(2)[4|0.4|CamScanner] CC2        8
# EC-EC(0)[8|90.2] CC3                  8
# EC-EC(0)[4|0.6] CC1                   8
# EC-EC(0)[4|90.3]                      8
# EC-EC(7)[8|0.1]                       8
# EC-EC(1)[2|0.3] SC                    8
# EC-EC(1)[4|90.4]                      8
# EC-EC(0)[4|0.3] CC1                   8
# EC-EC(1)[8|1.2|CamScanner]            8
# EC-EC(3)[4|0.4] CC1                   8
# EC-EC(4)[4|0.3]                       8
# EC-APP(1)[8|0.3|CamScanner]           8
# EC-EC(0)[2|89.7]                      8
# EC-EC(0)[8|0.7]                       8
# EC-EC(1)[2|0.1|CamScanner]            8
# EC-EC(2)[2|90.4]                      8
# EC-APP(1)[8|1.6]                      8
# EC-EC(1)[2|89.6]                      8
# EC-EC(2)[8|1.4|CamScanner]            8
# EC-EC(0)[4|0.2|CamScanner]            8
# EC-EC[1|0.1] SC                       8
# EC-EC(1)[4|1.1]                       8
# EC-EC(0)[8|0.5] CC1                   8
# EC-EC(1)[4|0.5|CamScanner]            8
# EC-EC(1)[4|0.7]                       8
# EC-EC(1)[4|1.0]                       8
# EC-EC(0)[8|0.3] CC2                   8
# EC-EC(2)[4|0.4] CC2                   8
# EC-EC(0)[7|3.2]                       7
# EC-EC(6)[7|90.4|CamScanner]           7
# EC-EC(0)[7|0.7]                       7
# EC-EC(0)[7|89.8]                      7
# NOM-IMSS3[1|0.6]                      7
# EC-EC(5)[7|90.6]                      7
# EC-EC(0)[7|0.2] CC1                   7
# EC-EC(0)[7|0.0]                       7
# EC-SUC(1)[7|0.6]                      7
# EC-EC(2)[7|0.4] CC3                   7
# EC-EC(4)[7|90.0|CamScanner]           7
# EC-EC(0)[7|0.6] CC1                   7
# EC-EC(2)[7|2.3]                       7
# EC-EC(0)[7|0.5] CC2                   7
# EC-EC[1|0.7]                          7
# EC-EC(1)[7|2.4]                       7
# EC-EC(6)[7|0.6]                       7
# EC-EC[1|0.0] CC1                      7
# EC-EC(7)[7|90.6]                      7
# EC-EC(0)[7|1.2]                       7
# EC-EC(1)[7|90.6|CamScanner]           7
# EC-EC(2)[7|90.5]                      7
# EC-EC(1)[7|2.0]                       7
# EC-EC(1)[7|0.8|CamScanner]            7
# EC-EC(2)[7|1.6]                       7
# EC-EC(1)[7|2.2] CC1                   7
# NOM-SEP(1)[1|0.5|CamScanner]          7
# EC-EC(5)[7|89.6]                      7
# EC-EC(2)[7|2.9]                       7
# EC-EC(2)[7|1.1]                       7
# EC-EC(1)[7|2.2]                       7
# EC-EC(3)[7|0.3]                       7
# EC-APP(1)[7|0.6]                      7
# EC-EC(4)[7|90.1]                      7
# EC-EC(1)[7|2.3]                       7
# EC-EC(1)[7|0.4|CamScanner]            7
# EC-EC(5)[7|0.1]                       7
# EC-EC(0)[7|1.2|CamScanner]            7
# EC-SUC(1)[7|0.5]                      7
# EC-EC(0)[7|1.5]                       7
# EC-EC(5)[7|90.5]                      7
# EC-APP(1)[7|0.2|CamScanner]           7
# EC-EC(5)[7|90.2]                      7
# EC-EC(1)[7|90.5]                      7
# EC-EC(1)[7|1.7|CamScanner]            7
# EC-EC(3)[7|1.5]                       7
# EC-EC(3)[7|0.5]                       7
# EC-EC(3)[7|0.2|CamScanner]            7
# EC-EC(1)[7|2.1]                       7
# EC-APP(1)[7|0.6|CamScanner]           7
# EC-EC(2)[7|1.2]                       7
# EC-EC(2)[7|1.0]                       7
# EC-EC(3)[7|90.1]                      7
# EC-EC(4)[7|0.3]                       7
# EC-APP(1)[7|0.1]                      7
# EC-EC(1)[7|1.4]                       7
# EC-APP(1)[7|1.1]                      7
# EC-EC(1)[7|1.3]                       7
# NOM-PEMEX[1|0.4|CamScanner]           7
# EC-APP(1)[7|0.1|CamScanner]           7
# EC-APP(1)[7|0.8]                      7
# EC-EC(0)[6|0.1] CC1                   6
# EC-SUC(1)[2|90.0|CamScanner]          6
# EC-EC(3)[6|0.5] SC                    6
# EC-EC(1)[6|3.1]                       6
# EC-EC(5)[6|90.5]                      6
# EC-SUC(1)[6|4.8]                      6
# EC-EC(1)[2|0.0] CC1                   6
# EC-EC(5)[6|90.4]                      6
# EC-EC(2)[6|89.8]                      6
# EC-EC(0)[2|0.4] CC2                   6
# EC-EC(2)[2|89.8]                      6
# EC-EC(0)[3|0.5] SC                    6
# EC-EC(1)[2|0.2] CC1                   6
# EC-EC(0)[6|4.0]                       6
# EC-EC(0)[6|0.2] SC                    6
# EC-SUC(1)[3|0.7]                      6
# EC-EC(0)[3|89.9]                      6
# EC-EC(0)[6|0.3] CC3                   6
# EC-EC(1)[3|0.9]                       6
# EC-APP(1)[6|0.4|CamScanner]           6
# EC-EC(0)[6|0.3] CC1                   6
# EC-EC(0)[6|1.1] CC2                   6
# EC-EC(2)[6|1.1]                       6
# EC-EC(0)[6|0.2] CC1                   6
# EC-ATM(1)[3|0.3]                      6
# EC-EC(0)[6|0.2|CamScanner]            6
# EC-EC(1)[6|2.4]                       6
# EC-EC(0)[3|0.0] CC1                   6
# EC-EC(6)[6|90.3]                      6
# EC-EC(0)[2|0.0] SC                    6
# EC-EC(1)[6|90.0]                      6
# EC-ATM(1)[3|0.4]                      6
# EC-EC(4)[6|0.5]                       6
# EC-SUC(1)[6|0.9]                      6
# EC-ATM(1)[2|0.8|CamScanner]           6
# EC-EC(0)[6|89.7]                      6
# EC-EC(1)[3|2.1]                       6
# EC-EC(2)[6|3.3]                       6
# EC-SUC(1)[3|0.2|CamScanner]           6
# EC-EC(2)[6|0.4|CamScanner]            6
# EC-EC(1)[3|1.5]                       6
# EC-EC(1)[6|3.0]                       6
# EC-EC(0)[2|0.5|CamScanner]            6
# EC-EC(1)[6|3.4]                       6
# EC-EC(1)[6|0.1|CamScanner]            6
# EC-EC(1)[6|2.1]                       6
# EC-ATM(1)[6|0.3]                      6
# EC-EC(3)[6|0.7]                       6
# EC-EC(7)[6|90.5]                      6
# EC-EC(1)[6|2.3]                       6
# EC-EC(0)[6|0.0]                       6
# EC-EC(2)[6|1.2]                       6
# EC-EC(0)[6|0.9]                       6
# EC-EC(2)[6|0.7]                       6
# EC-APP(1)[6|1.0]                      6
# EC-EC(1)[6|0.2|CamScanner]            6
# EC-EC[1|89.9]                         6
# EC-EC(0)[2|0.1] SC                    6
# EC-EC(0)[6|3.4]                       6
# EC-EC(0)[6|1.4]                       6
# EC-EC(0)[2|0.4] CC1                   6
# EC-EC(1)[3|0.3] CC1                   6
# EC-EC(2)[6|90.1]                      6
# EC-EC(0)[6|0.6] CC2                   6
# EC-EC(2)[6|0.6|CamScanner]            6
# EC-EC(0)[3|2.2]                       6
# EC-EC(6)[6|90.7]                      6
# EC-EC(3)[3|0.3]                       6
# EC-EC(0)[6|1.5]                       6
# EC-EC(1)[6|4.5]                       6
# EC-EC(4)[6|90.4]                      6
# EC-EC(0)[6|2.3]                       6
# EC-APP(1)[2|0.9]                      6
# EC-EC(0)[3|0.5] CC1                   6
# EC-EC(0)[2|89.9]                      6
# EC-EC(2)[6|0.0]                       6
# EC-EC(0)[6|1.1]                       6
# EC-SUC(1)[6|0.3|CamScanner]           6
# EC-APP(1)[6|0.7]                      6
# EC-EC(2)[3|89.5]                      6
# EC-SUC(1)[2|0.1|CamScanner]           6
# NOM-SEP(1)[1|0.2|CamScanner]          6
# EC-EC(3)[6|90.6]                      6
# EC-EC(1)[3|2.2]                       6
# EC-SUC(1)[6|0.4]                      6
# EC-EC(0)[2|90.5]                      6
# EC-EC(6)[6|91.9]                      6
# EC-EC(1)[3|89.9]                      6
# EC-EC(2)[6|3.0]                       6
# EC-EC(1)[3|1.3]                       6
# EC-EC(5)[6|90.2]                      6
# EC-EC(1)[3|1.1]                       6
# EC-ATM(1)[3|0.9]                      6
# EC-EC(1)[6|1.5]                       6
# EC-EC(1)[6|89.5|CamScanner]           6
# EC-EC(3)[3|89.6]                      6
# EC-EC(2)[2|90.1]                      6
# EC-EC(4)[6|90.5]                      6
# EC-EC(0)[2|0.9]                       6
# EC-EC(1)[6|0.4|CamScanner]            6
# EC-SUC(1)[3|0.7|CamScanner]           6
# EC-EC(0)[3|90.4]                      6
# EC-EC(2)[2|0.5]                       6
# EC-EC(1)[2|90.5]                      6
# EC-EC[1|90.1]                         6
# EC-APP(1)[2|0.1|CamScanner]           6
# EC-EC(1)[3|89.7]                      6
# EC-APP(1)[3|90.5]                     6
# NOM-PEMEX[1|0.2|CamScanner]           6
# EC-EC(1)[6|4.1]                       6
# EC-SUC[1|0.2|CamScanner]              6
# NOM-PEMEX[1|0.7]                      6
# EC-EC(0)[3|90.8]                      6
# EC-EC(0)[6|2.2]                       6
# EC-EC(2)[6|1.3]                       6
# EC-EC(0)[3|0.3|CamScanner]            6
# EC-EC(5)[6|90.1]                      6
# EC-EC(2)[6|89.9|CamScanner]           6
# EC-APP(1)[6|0.9]                      6
# EC-EC(6)[6|90.6]                      6
# EC-EC[1|90.5]                         6
# NOM-ISSSTE[1|0.8]                     6
# EC-EC(0)[6|0.5|CamScanner]            6
# EC-APP(1)[2|90.0]                     6
# EC-EC(0)[2|1.2]                       6
# EC-APP(1)[6|1.3]                      6
# EC-EC(2)[3|90.1]                      6
# EC-EC(4)[6|0.8]                       6
# EC-EC(2)[3|89.7]                      6
# EC-SUC[1|0.1|CamScanner]              6
# EC-APP(1)[3|0.8]                      6
# EC-SUC(1)[3|1.4]                      6
# EC-ATM(1)[3|0.4|CamScanner]           6
# EC-EC(1)[6|0.3|CamScanner]            6
# EC-ATM(1)[6|91.1]                     6
# EC-EC(3)[6|0.2]                       6
# EC-EC(0)[2|89.6]                      6
# NOM-IMSS3[1|1.0]                      6
# EC-EC(1)[2|90.1]                      6
# EC-APP(1)[3|0.6|CamScanner]           6
# EC-SUC(1)[6|0.5]                      6
# EC-EC(0)[6|1.2]                       6
# EC-EC(0)[6|90.4]                      6
# EC-EC(3)[3|91.1]                      6
# EC-EC(0)[6|0.7]                       6
# EC-EC(3)[6|1.6]                       6
# NOM-IMSS[1|90.5]                      6
# EC-EC(0)[2|1.4]                       6
# EC-ATM(1)[3|0.2]                      6
# EC-EC(2)[5|2.4]                       5
# EC-ATM(1)[5|0.5]                      5
# EC-EC(0)[5|0.4] SC                    5
# EC-EC(1)[5|2.2]                       5
# EC-EC(0)[5|2.2]                       5
# EC-APP(1)[5|90.0]                     5
# EC-ATM(1)[5|92.5]                     5
# EC-EC(0)[5|0.3] CC1                   5
# EC-EC(0)[5|90.2|CamScanner] CC2       5
# EC-EC(0)[5|0.2] SC                    5
# EC-EC(2)[5|90.2]                      5
# EC-EC(0)[5|0.5|CamScanner]            5
# EC-ATM(1)[5|9.6]                      5
# EC-EC(3)[5|0.4] CC1                   5
# EC-ATM(1)[1|0.6]                      5
# EC-EC(3)[5|90.0]                      5
# EC-EC(0)[5|0.3] CC3                   5
# EC-EC(2)[5|0.0]                       5
# EC-EC(0)[5|1.1]                       5
# EC-EC(4)[5|0.5]                       5
# EC-EC(3)[5|90.0|CamScanner]           5
# EC-ATM(1)[5|2.3]                      5
# EC-EC(1)[5|0.9]                       5
# EC-EC(4)[5|0.6]                       5
# EC-EC(0)[5|1.0]                       5
# EC-EC[1|0.6]                          5
# EC-EC(0)[5|3.2]                       5
# EC-APP(1)[5|0.1|CamScanner]           5
# EC-EC(4)[5|89.8]                      5
# EC-EC(0)[5|90.5]                      5
# EC-EC(2)[5|1.1]                       5
# EC-EC(3)[5|90.3]                      5
# EC-EC(0)[5|0.3] CC2                   5
# EC-EC(1)[5|90.5]                      5
# EC-EC(3)[5|90.2]                      5
# EC-EC(1)[5|3.2] CC1                   5
# EC-APP(1)[5|1.0]                      5
# EC-ATM(1)[5|0.4]                      5
# EC-ATM(1)[5|1.6]                      5
# EC-SUC(1)[5|90.5]                     5
# EC-APP(1)[5|3.1]                      5
# NOM-IMSS3[1|0.7]                      5
# EC-EC(2)[5|0.9]                       5
# EC-EC(0)[5|0.4|CamScanner]            5
# NOM-IMSS[1|0.4|CamScanner]            5
# EC-EC(0)[5|90.4] SC                   5
# EC-EC(5)[5|90.2]                      5
# EC-EC(2)[5|3.6]                       5
# EC-EC(2)[5|0.6|CamScanner]            5
# EC-EC(0)[5|90.4] CC2                  5
# EC-ATM(1)[5|1.8]                      5
# EC-EC(2)[5|90.4]                      5
# EC-EC(1)[5|0.8|CamScanner]            5
# EC-EC(2)[5|90.0]                      5
# EC-EC(1)[5|88.6]                      5
# EC-EC(0)[5|2.3]                       5
# EC-EC(1)[5|2.1]                       5
# EC-EC(1)[5|5.4]                       5
# EC-EC(1)[5|0.3] CC1                   5
# EC-APP(1)[5|0.9|CamScanner]           5
# EC-ATM(1)[5|0.7]                      5
# EC-EC(2)[5|0.6]                       5
# EC-EC(0)[5|0.2|CamScanner]            5
# EC-APP(1)[1|0.5]                      5
# EC-APP(1)[5|0.0]                      5
# EC-EC(4)[5|90.3]                      5
# EC-EC(2)[5|1.0]                       5
# EC-EC(2)[5|0.1|CamScanner]            5
# EC-EC(5)[5|90.5]                      5
# EC-EC(0)[5|89.6]                      5
# EC-EC(5)[5|89.6]                      5
# EC-EC(1)[5|90.0|CamScanner]           5
# NOM-IMSS3[1|90.0]                     5
# EC-ATM(1)[1|1.2]                      5
# EC-EC(4)[5|89.9]                      5
# EC-EC(0)[5|1.9]                       5
# EC-EC(6)[5|90.2]                      5
# EC-EC(0)[5|90.6]                      5
# EC-EC(0)[5|0.3] SC                    5
# EC-EC(2)[5|90.7]                      5
# EC-EC(0)[5|90.0|CamScanner]           5
# EC-EC(1)[5|0.7]                       5
# EC-EC(0)[5|90.4|CamScanner]           5
# EC-EC(1)[5|4.1]                       5
# EC-SUC(1)[5|0.1]                      5
# EC-EC(1)[5|90.6]                      5
# EC-SUC(1)[5|0.7]                      5
# EC-SUC[1|0.7|CamScanner]              5
# EC-EC(0)[5|5.2]                       5
# EC-SUC(1)[2|0.6]                      4
# EC-EC(0)[4|90.5]                      4
# EC-SUC(1)[4|0.8|CamScanner]           4
# EC-APP(1)[4|90.6]                     4
# EC-ATM(1)[4|0.5]                      4
# EC-EC(1)[4|2.2]                       4
# EC-EC(0)[4|90.2|CamScanner]           4
# EC-APP(1)[2|1.3]                      4
# EC-EC(4)[4|90.3]                      4
# EC-EC(1)[2|0.1] CC1                   4
# EC-EC(1)[4|4.1]                       4
# EC-EC(1)[4|89.6]                      4
# EC-EC(1)[4|5.5]                       4
# EC-EC(4)[4|90.2]                      4
# EC-EC(0)[4|0.1] CC1                   4
# EC-ATM(1)[2|0.1|CamScanner]           4
# EC-APP(1)[4|1.4]                      4
# NOM-SEP(1)[1|0.1|CamScanner]          4
# EC-EC(2)[4|90.7|CamScanner]           4
# EC-SUC(1)[2|0.5|CamScanner]           4
# EC-ATM(1)[4|5.5]                      4
# EC-EC(0)[4|1.0] SC                    4
# EC-EC(1)[4|90.5]                      4
# EC-APP(1)[2|90.2]                     4
# NOM-IMSS[1|1.0]                       4
# EC-ATM(1)[2|1.5]                      4
# EC-ATM(1)[4|0.8]                      4
# EC-APP(1)[4|90.4]                     4
# EC-EC(4)[4|90.6]                      4
# EC-APP(1)[4|2.9]                      4
# EC-EC[1|1.1]                          4
# EC-EC(0)[2|0.1|CamScanner]            4
# EC-ATM(1)[4|1.1]                      4
# EC-EC(3)[4|6.5]                       4
# EC-ATM(1)[4|3.1]                      4
# EC-SUC(1)[4|90.1]                     4
# EC-ATM(1)[4|2.0]                      4
# ...
# EC-EC(0)[3|1.4]                       3
# CDOM-AGUA[1|1.1]                      3
# EC-ATM(1)[3|0.3|CamScanner]           3
# EC-EC(0)[3|89.7]                      3
# EC-EC(1)[3|89.5]                      3
# ID-INE(1)[1|90.0]                     3
# EC-EC(0)[3|0.5|CamScanner]            3
# CDOM-CFE[1|1.7]                       3
# EC-SUC[1|0.5|CamScanner]              3
# ID-INE(1)[1|3.2]                      3
# CDOM-AGUA[1|1.3]                      3
# CDOM-AGUA[1|89.6]                     3
# EC-SUC[1|1.4]                         3
# EC-EC(3)[3|89.5]                      3
# EC-EC(0)[3|0.7]                       3
# EC-APP(1)[3|0.5|CamScanner]           3
# NOM-SEP(1)[1|0.4|CamScanner]          3
# EC-EC(3)[3|89.7]                      3
# EC-ATM(1)[3|2.1|CamScanner]           3
# EC-SUC(1)[3|90.0|CamScanner]          3
# EC-APP(1)[3|0.1|CamScanner]           3
# EC-EC(3)[3|90.4]                      3
# EC-EC(0)[3|1.6]                       3
# EC-SUC(1)[3|0.5|CamScanner]           3
# EC-APP(1)[3|0.3|CamScanner]           3
# NOM-IMSS[1|1.4]                       3
# EC-EC(0)[3|90.2]                      3
# EC-EC(2)[3|90.7]                      3
# EC-SUC(1)[3|1.6]                      3
# EC-APP(1)[3|1.7]                      3
# EC-APP(1)[3|1.4]                      3
# EC-EC(1)[3|3.5]                       3
# EC-EC[1|89.5]                         3
# EC-EC(0)[3|0.0|CamScanner]            3
# EC-ATM(1)[3|0.6|CamScanner]           3
# EC-ATM(1)[1|1.9]                      3
# EC-EC(2)[3|90.4]                      3
# NOM-PEMEX[1|0.1|CamScanner]           3
# EC-EC(3)[3|89.9|CamScanner]           3
# EC-SUC(1)[3|1.1]                      3
# EC-EC(4)[3|90.3]                      3
# EC-EC(3)[3|90.1]                      3
# EC-EC(3)[3|0.2]                       3
# EC-EC(1)[3|1.6]                       3
# EC-SUC(1)[3|2.6]                      3
# EC-ATM(1)[1|0.9]                      3
# EC-EC(2)[3|0.6]                       3
# EC-EC(1)[3|90.5]                      3
# EC-EC(1)[3|1.7]                       3
# EC-EC(3)[3|89.6|CamScanner]           3
# EC-EC(2)[2|90.3]                      2
# EC-EC(2)[2|89.6]                      2
# EC-SUC(1)[2|16.4]                     2
# EC-EC(2)[2|0.3] CC3                   2
# ID-INE(1)[1|2.2] CC1                  2
# EC-ATM(1)[2|1.9|CamScanner]           2
# NOM-ISSSTE[1|89.8]                    2
# NOM-ISSSTE[1|90.3]                    2
# EC-ATM(1)[1|1.4]                      2
# EC-EC(2)[2|89.5]                      2
# EC-EC(1)[2|0.1] SC                    2
# EC-ATM(1)[2|0.0|CamScanner]           2
# EC-EC(0)[2|0.6|CamScanner]            2
# EC-EC(0)[2|3.2]                       2
# EC-ATM(1)[2|0.9|CamScanner]           2
# EC-EC(0)[2|4.6]                       2
# EC-SUC(1)[2|90.8|CamScanner]          2
# EC-EC(2)[2|90.0|CamScanner]           2
# EC-EC(1)[2|89.7|CamScanner]           2
# CDOM-AGUA[1|90.5]                     2
# NOM-IMSS3[1|0.1|CamScanner]           2
# EC-EC(0)[2|91.3|CamScanner]           2
# EC-EC(0)[2|89.6|CamScanner]           2
# CDOM-GAS[1|0.4]                       2
# EC-SUC(1)[2|2.0|CamScanner]           2
# EC-EC(0)[2|2.1]                       2
# ID-INE(1)[1|1.5] CC1                  2
# EC-SUC(1)[2|1.5]                      2
# EC-EC[1|0.2] CC1                      2
# EC-EC(0)[2|4.2]                       2
# EC-EC(1)[2|90.0|CamScanner]           2
# CDOM-GAS[1|0.7]                       2
# EC-ATM(1)[2|91.5]                     2
# EC-EC(2)[2|0.3|CamScanner]            2
# EC-EC(0)[2|1.5] SC                    2
# EC-EC(0)[2|0.1] CC2                   2
# NOM-IMSS[1|89.4]                      2
# EC-EC(2)[2|0.0|CamScanner]            2
# CDOM-CFE[1|1.2]                       2
# EC-ATM(1)[1|2.3]                      2
# CDOM-AGUA[1|2.4]                      2
# CDOM-CFE[1|0.6|CamScanner]            2
# EC-EC(2)[2|90.2]                      2
# EC-EC(0)[2|90.1] SC                   2
# CDOM-TEL[1|0.6]                       2
# EC-ATM(1)[2|0.5|CamScanner]           2
# EC-EC(0)[2|90.7]                      2
# CDOM-GAS[1|0.5]                       2
# CDOM-CFE[1|2.1]                       2
# ID-INE(1)[1|4.1]                      2
# EC-EC(1)[2|0.6|CamScanner]            2
# EC-APP(1)[1|89.5]                     2
# EC-ATM(1)[2|0.8]                      2
# EC-ATM(1)[2|38.3]                     2
# CDOM-AGUA[1|0.3|CamScanner]           2
# EC-EC[1|0.1|CamScanner] SC            2
# EC-APP(1)[2|91.2]                     2
# EC-EC(1)[2|0.8|CamScanner]            2
# CDOM-CONST[1|0.9]                     2
# NOM-PEMEX[1|0.3|CamScanner]           2
# EC-EC(0)[2|1.9]                       2
# NOM-ISSSTE[1|89.5]                    2
# EC-EC(0)[2|90.2]                      2
# EC-EC(3)[2|0.3]                       2
# EC-APP(1)[2|5.1]                      2
# CDOM-AGUA[1|2.8]                      2
# EC-EC(0)[2|3.5]                       2
# EC-EC[1|0.5|CamScanner]               2
# EC-ATM(1)[2|1.0]                      2
# NOM-PEMEX[1|1.3]                      2
# EC-EC(0)[2|2.2]                       2
# ID-PASS[1|0.4]                        2
# EC-EC(1)[2|0.8]                       2
# EC-EC[1|0.6|CamScanner]               2
# EC-SUC[1|1.6]                         2
# EC-EC(0)[2|0.7]                       2
# EC-ATM(1)[2|1.2|CamScanner]           2
# EC-SUC(1)[2|90.4]                     2
# EC-SUC(1)[2|0.9|CamScanner]           2
# EC-EC(1)[2|0.9] CC1                   2
# CDOM-AGUA[1|0.5|CamScanner]           2
# EC-ATM(1)[2|0.0]                      2
# EC-SUC(1)[2|1.8]                      2
# EC-ATM(1)[2|1.6]                      2
# EC-SUC(1)[2|90.3]                     2
# EC-EC(1)[2|0.1|CamScanner] CC1        2
# EC-EC(0)[2|6.4|CamScanner]            2
# EC-APP(1)[2|89.8]                     2
# EC-ATM(1)[2|4.0]                      2
# EC-APP(1)[2|7.3]                      2
# EC-ATM(1)[2|1.7]                      2
# ID-INE(1)[1|2.4] CC1                  2
# ID-INE(1)[1|4.6]                      2
# EC-EC(1)[2|4.3]                       2
# EC-EC(2)[2|89.9]                      2
# EC-EC(1)[2|1.1]                       2
# NOM-IMSS[1|89.3]                      2
# EC-EC(0)[2|90.4|CamScanner]           2
# ID-INE(2)[1|0.5]                      2
# EC-EC(0)[2|2.3]                       2
# EC-SUC[1|0.6]                         2
# EC-EC(0)[2|90.6|CamScanner]           2
# EC-EC(1)[2|89.4]                      2
# EC-APP(1)[2|90.3]                     2
# EC-EC(1)[2|89.8|CamScanner]           2
# CDOM-AGUA[1|1.5]                      2
# EC-APP(1)[2|0.3|CamScanner]           2
# EC-ATM(1)[1|3.8]                      2
# EC-EC(0)[2|2.4]                       2
# CDOM-AGUA[1|1.8]                      2
# EC-SUC(1)[2|90.0]                     2
# EC-EC(2)[2|90.6]                      2
# EC-SUC(1)[2|2.0]                      2
# CDOM-TEL[1|0.3|CamScanner]            2
# EC-EC(0)[2|3.3]                       2
# EC-APP(1)[1|90.4]                     2
# CDOM-CONST[1|0.2|CamScanner]          2
# EC-EC(0)[2|1.2] SC                    2
# EC-EC[1|0.4] SC                       2
# ID-INE(2)[1|1.2]                      2
# EC-APP(1)[2|1.7]                      2
# EC-SUC(1)[2|89.6]                     2
# EC-SUC(1)[2|1.1]                      2
# CDOM-AGUA[1|1.6]                      2
# EC-EC(1)[2|90.6|CamScanner]           2
# EC-SUC(1)[2|1.2]                      2
# ID-INE(1)[1|90.6]                     2
# EC-SUC(1)[2|0.8|CamScanner]           2
# EC-EC(1)[2|0.4] SC                    2
# EC-ATM(1)[2|1.1|CamScanner]           2
# EC-EC(0)[2|2.9|CamScanner]            2
# EC-EC(3)[2|90.0]                      2
# EC-EC(1)[2|0.4] CC1                   2
# EC-EC(1)[2|0.5] CC1                   2
# EC-EC(1)[2|1.2]                       2
# EC-EC(3)[2|0.1]                       2
# CDOM-CABLE[1|0.0|CamScanner]          2
# EC-ATM(1)[2|1.9]                      2
# NOM-ISSSTE[1|89.7]                    2
# EC-APP(1)[2|90.1]                     2
# CDOM-CFE[1|1.1]                       2
# NOM-ISSSTE[1|90.2]                    1
# ID-INE(2)[1|1.3]                      1
# NOM-PEMEX[1|0.7|CamScanner]           1
# ID-INE(1)[1|1.8] CC1                  1
# EC-EC[1|90.4|CamScanner]              1
# EC-SUC[1|90.2]                        1
# NOM-SEP(1)[1|0.9]                     1
# EC-EC[1|0.3] SC                       1
# NOM-ISSSTE[1|0.7|CamScanner]          1
# ID-INE(1)[1|90.0] CC1                 1
# EC-EC[1|89.0]                         1
# EC-EC[1|91.3]                         1
# ID-INE(1)[1|2.0] CC1                  1
# ID-INE(1)[1|3.1] CC1                  1
# NOM-ISSSTE[1|0.3|CamScanner]          1
# ID-INE(1)[1|2.7] CC1                  1
# NOM-IMSS3[1|89.6]                     1
# NOM-ISSSTE[1|1.6]                     1
# EC-EC[1|90.8]                         1
# EC-EC[1|90.3] SC                      1
# EC-EC[1|90.9|CamScanner]              1
# EC-EC[1|1.3]                          1
# CDOM-TEL[1|0.1|CamScanner]            1
# CDOM-CABLE[1|0.4|CamScanner]          1
# CDOM-AGUA[1|90.3|CamScanner]          1
# EC-ATM(1)[1|0.5|CamScanner]           1
# ID-PASS[1|0.2]                        1
# CDOM-TEL[1|1.0]                       1
# ID-INE(1)[1|4.5] CC1                  1
# EC-ATM(1)[1|3.7]                      1
# CDOM-AGUA[1|2.2]                      1
# CDOM-CFE[1|1.0]                       1
# ID-PASS[1|0.5] CC1                    1
# EC-SUC[1|0.7]                         1
# EC-EC[1|89.6] SC                      1
# EC-SUC[1|1.8]                         1
# ID-INE(1)[1|4.0]                      1
# CDOM-CFE[1|90.3]                      1
# EC-SUC[1|90.9]                        1
# ID-INE(1)[1|2.1] CC1                  1
# CDOM-TEL[1|0.6|CamScanner]            1
# NOM-PEMEX[1|1.2]                      1
# NOM-PEMEX[1|1.4]                      1
# EC-ATM(1)[1|5.2]                      1
# EC-ATM(1)[1|89.1]                     1
# NOM-IMSS[1|0.7|CamScanner]            1
# CDOM-AGUA[1|90.0|CamScanner]          1
# NOM-IMSS[1|89.1]                      1
# ID-INE(1)[1|3.5] CC1                  1
# CDOM-CFE[1|1.1|CamScanner]            1
# EC-EC[1|0.3] CC1                      1
# ID-PASS[1|90.0|CamScanner]            1
# EC-ATM(1)[1|7.0|CamScanner]           1
# EC-EC[1|90.3|CamScanner]              1
# ID-INE(1)[1|89.4]                     1
# EC-SUC[1|1.1]                         1
# EC-EC[1|89.8|CamScanner]              1
# ID-INE(1)[1|89.1]                     1
# NOM-IMSS[1|90.8]                      1
# CDOM-GAS[1|90.0]                      1
# ID-INE(1)[1|1.9] CC1                  1
# ID-INE(2)[1|1.4]                      1
# ID-INE(1)[1|91.0]                     1
# CDOM-AGUA[1|2.0]                      1
# EC-SUC[1|89.9]                        1
# EC-ATM(1)[1|27.6]                     1
# ID-INE(2)[1|2.1]                      1
# CDOM-CFE[1|0.8|CamScanner]            1
# EC-ATM(1)[1|4.4]                      1
# NOM-ISSSTE[1|0.4|CamScanner]          1
# EC-EC[1|1.3|CamScanner]               1
# NOM-IMSS3[1|90.3]                     1
# CDOM-TEL[1|1.7]                       1
# NOM-PEMEX[1|89.9|CamScanner]          1
# NOM-PEMEX[1|0.5|CamScanner]           1
# NOM-PEMEX[1|91.1]                     1
# NOM-PEMEX[1|90.4]                     1
# NOM-PEMEX[1|90.3]                     1
# NOM-PEMEX[1|90.7]                     1
# NOM-PEMEX[1|90.3|CamScanner]          1
# NOM-IMSS[1|0.6|CamScanner]            1
# NOM-ISSSTE[1|1.1]                     1
# NOM-IMSS[1|90.1|CamScanner]           1
# CDOM-CONST[1|0.0|CamScanner]          1
# EC-EC[1|1.6]                          1
# ID-INE(1)[1|2.9|CamScanner]           1
# CDOM-CABLE[1|0.5]                     1
# NOM-IMSS[1|90.0|CamScanner]           1
# ID-INE(1)[1|1.8|CamScanner]           1
# ID-PASS[1|0.0]                        1
# NOM-IMSS3[1|89.7]                     1
# EC-SUC[1|0.8|CamScanner]              1
# ID-INE(1)[1|3.1|CamScanner]           1
# NOM-IMSS3[1|1.5]                      1
# NOM-IMSS3[1|0.2|CamScanner]           1
# NOM-IMSS[1|1.3]                       1
# CDOM-AGUA[1|3.4]                      1
# ID-PASS[1|0.1]                        1
# EC-ATM(1)[1|22.5]                     1
# EC-APP(1)[1|90.6]                     1
# EC-EC[1|89.4]                         1
# EC-SUC[1|89.7|CamScanner]             1
# EC-SUC[1|1.0|CamScanner]              1
# ID-INE(1)[1|103.4]                    1
# NOM-IMSS[1|1.1]                       1
# CDOM-CFE[1|0.9|CamScanner]            1
# ID-INE(2)[1|1.0]                      1
# EC-ATM(1)[1|5.8]                      1
# ID-INE(1)[1|89.9]                     1
# EC-SUC[1|1.0]                         1
# EC-SUC[1|0.8]                         1
# CDOM-CFE[1|8.3]                       1
# ID-INE(1)[1|89.7]                     1
# NOM-IMSS[1|89.7|CamScanner]           1
# EC-SUC[1|0.6|CamScanner]              1
# ID-INE(1)[1|8.2]                      1
# CDOM-CFE[1|89.7]                      1
# EC-ATM(1)[1|4.0]                      1
# EC-ATM(1)[1|5.3]                      1
# CDOM-GAS[1|0.0|CamScanner]            1
# EC-ATM(1)[1|89.8]                     1
# NOM-PEMEX[1|0.6|CamScanner]           1
# EC-APP(1)[1|0.9]                      1
# ID-INE(1)[1|89.5|CamScanner]          1
# NOM-IMSS[1|2.3]                       1
# ID-INE(2)[1|2.0]                      1
# CDOM-AGUA[1|89.4]                     1
# NOM-IMSS[1|1.8]                       1
# EC-EC[1|90.0|CamScanner]              1
# ID-INE(1)[1|5.1]                      1
# CDOM-AGUA[1|1.9]                      1
# EC-EC[1|1.0]                          1
# EC-ATM(1)[1|2.8]                      1
# CDOM-AGUA[1|2.1]                      1
# CDOM-CONST[1|0.5|CamScanner]          1
# EC-ATM(1)[1|89.7]                     1
# EC-SUC[1|90.3]                        1
# EC-ATM(1)[1|1.3|CamScanner]           1
# CDOM-AGUA[1|4.6]                      1
# CDOM-AGUA[1|0.7|CamScanner]           1
# ID-INE(1)[1|5.9]                      1
# CDOM-GAS[1|1.5]                       1
# EC-SUC[1|89.2|CamScanner]             1
# NOM-ISSSTE[1|1.0]                     1
# EC-APP(1)[1|89.7]                     1
# CDOM-CFE[1|2.7]                       1
# EC-ATM(1)[1|3.6]                      1
# EC-ATM(1)[1|89.6]                     1
# EC-EC[1|90.7]                         1
# ID-INE(1)[1|6.0]                      1
# CDOM-CFE[1|1.8]                       1
# CDOM-CFE[1|89.8]                      1
# ID-INE(1)[1|4.7]                      1
# EC-EC[1|90.5|CamScanner]              1
# ID-INE(1)[1|88.4]                     1
# EC-EC[1|0.9]                          1
# CDOM-GAS[1|1.1]                       1
# EC-EC[1|90.5] SC                      1
# NOM-ISSSTE[1|1.8]                     1
# ID-INE(1)[1|9.6]                      1
# CDOM-AGUA[1|1.7|CamScanner]           1
# EC-SUC[1|89.1|CamScanner]             1
# ID-INE(2)[1|0.1]                      1
# NOM-IMSS3[1|0.3|CamScanner]           1
# NOM-IMSS3[1|0.4|CamScanner]           1
# ID-PASS[1|0.5]                        1
# CDOM-CFE[1|1.6]                       1
# NOM-SEP(1)[1|1.1]                     1
# EC-SUC[1|1.5]                         1
# EC-APP(1)[1|88.7]                     1
# EC-ATM(1)[1|0.3|CamScanner]           1
# EC-APP(1)[1|90.2]                     1
# NOM-ISSSTE[1|3.2]                     1
# NOM-IMSS[1|1.2]                       1
# ID-INE(1)[1|1.7|CamScanner]           1
# EC-SUC[1|2.7]                         1
# CDOM-AGUA[1|1.7]                      1
# EC-APP(1)[1|0.6]                      1
# NOM-SEP(1)[1|0.6|CamScanner]          1
# EC-ATM(1)[1|1.5]                      1
# ID-INE(1)[1|90.5|CamScanner]          1
# EC-APP(1)[1|89.6]                     1
# CDOM-AGUA[1|90.1|CamScanner]          1
# CDOM-CFE[1|0.5|CamScanner]            1
# ID-PASS[1|0.9]                        1
# EC-SUC[1|89.7]                        1
# EC-APP(1)[1|2.2]                      1
# EC-SUC[1|90.4]                        1
# CDOM-TEL[1|0.9]                       1
# ID-PASS[1|0.3]                        1
# CDOM-AGUA[1|2.7]                      1
# CDOM-AGUA[1|91.2]                     1
# EC-APP(1)[1|90.3]                     1
# CDOM-AGUA[1|90.6]                     1
# ID-INE(1)[1|89.8]                     1
# EC-APP(1)[1|1.5]                      1
# ID-INE(1)[1|9.0]                      1
# ID-INE(1)[1|90.7]                     1
# EC-EC[1|2.7]                          1
# ID-INE(1)[1|2.8] CC1                  1
# Name: count, dtype: int64
# -----
# DocType
# EC        26556
# INE        9336
# IMSS       5453
# CFE        4512
# APP        4261
# CLIB       3501
# SUC        2581
# ISSSTE     2077
# SEP        1360
# PEMEX       865
# ATM         742
# AGUA        726
# IMSS3       438
# TEL         224
# CABLE       179
# CONST        78
# GAS          61
# PASS         10
# Name: count, dtype: int64
# -----

# %% [markdown]
# # Spoting Outliers

# %% [markdown]
# After analyzing the outliers across the columns, we can draw a few conclusions about the classification project:
#
# The column with the highest number of outliers is "Clarity" of the page. However, after calculating the percentage of outliers, we found that they account for only 8.70% of the total data. This suggests that while clarity does have some outliers, the proportion is not significant enough to negatively impact our classification model.
#
# Only one column, "Fields," did not report any outliers. However, this column does not provide meaningful information about the actual content of the images. To better understand its relevance to the classification task, it is necessary to request further clarification regarding the meaning and significance of each column in the dataset.

# %%
numeric_df = df.select_dtypes(include=["number"])
numeric_df = numeric_df.drop("Index", axis=1)


Q1 = numeric_df.quantile(0.25)  
Q3 = numeric_df.quantile(0.75) 
IQR = Q3 - Q1          

outliers = ((numeric_df < (Q1 - 1.5 * IQR)) | (numeric_df > (Q3 + 1.5 * IQR)))
outliers.sum()
# Out:
# Page               4005
# TotalPages          231
# PagesProcessed     3017
# Fields                0
# EmptyFields       11194
# ConfR              5641
# ConfA                57
# ConfW              3067
# Sharpness          5005
# Contrast           1218
# Clarity            5472
# Resolution         1275
# dtype: int64

# %%
numeric_df.describe()
# Out:
#                Page    TotalPages  PagesProcessed        Fields   EmptyFields  \
# count  62960.000000  62960.000000    62960.000000  62960.000000  62960.000000
# mean       2.934593      5.942186        3.326938     12.881210      3.495426
# std        3.068428      4.682230        3.418311     13.533471      6.201645
# min        1.000000      1.000000        1.000000      0.000000      0.000000
# 25%        1.000000      2.000000        1.000000      0.000000      0.000000
# 50%        2.000000      6.000000        1.000000     12.000000      0.000000
# 75%        4.000000      8.000000        5.000000     27.000000      3.000000
# max       48.000000     48.000000       15.000000     38.000000     21.000000
#
#               ConfR         ConfA         ConfW     Sharpness      Contrast  \
# count  62960.000000  62960.000000  62960.000000  62960.000000  62960.000000
# mean       0.917741      0.791809      0.879958    224.199117     43.402370
# std        0.128916      0.149599      0.091764    271.111842     11.423269
# min        0.001000      0.288000      0.152000      0.000000      0.000000
# 25%        0.914000      0.699000      0.849000     92.000000     36.000000
# 50%        0.956000      0.841000      0.904000    153.000000     43.000000
# 75%        0.993000      0.915000      0.930000    232.000000     50.000000
# max        0.999000      0.984000      0.993000  10209.000000    124.000000
#
#              Clarity    Resolution
# count   62960.000000  62960.000000
# mean    10422.152731    457.302506
# std     14534.007181    200.917008
# min         0.000000      0.000000
# 25%      3612.000000    321.000000
# 50%      6363.000000    429.000000
# 75%      9869.000000    568.229623
# max    514200.000000   2405.000000

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=numeric_df)
plt.xticks(rotation=90)
plt.title("Boxplot for Outlier Detection")
plt.show()

# %%
sns.boxplot(x=df["Clarity"])
plt.title("Boxplot for Outlier on Clarity")
plt.show()

# %%
column = "Clarity"
plt.hist(df[column], bins=30, edgecolor="black")
plt.xlabel(column)
plt.ylabel("Frequency")
plt.title(f"Skew Distribution on {column}")
plt.show()

# %%
Q1 = df["Clarity"].quantile(0.25)  
Q3 = df["Clarity"].quantile(0.75)  
IQR = Q3 - Q1  
 
outliers = df[(df["Clarity"] < (Q1 - 1.5 * IQR)) | (df["Clarity"] > (Q3 + 1.5 * IQR))]
percentage = round((len(outliers) / len(df)) * 100,3)

print(f"{percentage} % of outliers on Clarity")
# Out:
# 8.691 % of outliers on Clarity
